# %%
from matplotlib import pyplot as plt
import numpy as np
import matrixprofile as mp

# %matplotlib inline
plt.rcParams['figure.figsize'] = 20,16

# %%
import pandas as pd
data_set = r'C:\Users\renb\Documents\21_Github\tsaysis_tsod\NAB\data'
from pathlib import Path
folder_path = Path(data_set)
ts= pd.read_csv(folder_path.joinpath('artificialWithAnomaly/art_daily_flatmiddle.csv'))['value'].values

# %%
window_size = 300
window_st = ts[0:window_size]
plt.plot(np.arange(ts.shape[0]), ts)
plt.plot(np.arange(window_st.shape[0]), window_st)

# %%
profile, figures = mp.analyze(ts)
# Out:
# C:\Users\renb\Miniconda3\envs\iindustry_comp\lib\site-packages\matrixprofile\visualize.py:433: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# C:\Users\renb\Miniconda3\envs\iindustry_comp\lib\site-packages\matrixprofile\visualize.py:433: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# C:\Users\renb\Miniconda3\envs\iindustry_comp\lib\site-packages\matrixprofile\visualize.py:433: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %%
profile, figures = mp.analyze(ts,windows=300)
# Out:
# C:\Users\renb\Miniconda3\envs\iindustry_comp\lib\site-packages\matrixprofile\visualize.py:375: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %%
profile, figures = mp.analyze(ts,windows=900)
# Out:
# C:\Users\renb\Miniconda3\envs\iindustry_comp\lib\site-packages\matrixprofile\visualize.py:375: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %%
profile, figures = mp.analyze(ts,windows=8)
# Out:
# C:\Users\renb\Miniconda3\envs\iindustry_comp\lib\site-packages\matrixprofile\visualize.py:375: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
